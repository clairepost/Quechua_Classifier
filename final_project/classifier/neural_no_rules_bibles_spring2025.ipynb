# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer,  DataCollatorWithPadding
from transformers import get_scheduler
import torch
from datasets import Dataset, DatasetDict
import pandas as pd
import os
import re
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from torch.utils.data import DataLoader, RandomSampler
from torch.nn.utils.rnn import pad_sequence

# new file
from rules_polypersonal_combo import preprocess_texts

# %%
# Define the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("Llamacha/QuBERTa")
model = AutoModelForSequenceClassification.from_pretrained("Llamacha/QuBERTa", num_labels=27)  # adjust num_labels as necessary
# Out:
# Some weights of the model checkpoint at Llamacha/QuBERTa were not used when initializing RobertaForSequenceClassification: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at Llamacha/QuBERTa and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def split_document(text, max_length=250, overlap=50):
    # Split text into words
    words = text.split()
    parts = []
    if len(words) <= max_length:
        return [text]  # Return the entire text if it's short enough

    i = 0
    while i < len(words):
        # Ensure that we don't exceed the text length
        end_index = min(i + max_length, len(words))
        # Join the selected range of words back into a string
        chunk_text = " ".join(words[i:end_index])
        parts.append(chunk_text)
        i += (max_length - overlap)
    
    return parts

# %%
def remove_numbers(text):
    # Remove numbers using regular expression
    text_without_numbers = re.sub(r'\d+', '', text)
    return text_without_numbers

# %%
def load_and_preprocess(directory_paths):
    processed_data = []
    label_dict = {dialect: idx for idx, dialect in enumerate(directory_paths.keys())}
    
    for dialect, directory_path in directory_paths.items():
        print("dialect:", dialect)
        for filename in os.listdir(directory_path):
            if filename.endswith('.txt'):
                print("filename:", filename)
                file_path = os.path.join(directory_path, filename)
                
                with open(file_path, 'r', encoding='latin-1') as file:
                    text = file.read().strip()
                    text = remove_numbers(text)
                    
                    # Split the original text into chunks
                    chunks = split_document(text)
                    print("document is in", len(chunks), "chunks")
                    
                    # Process each chunk without any tags
                    for chunk in chunks:
                        encoded_text = tokenizer(
                            chunk,
                            truncation=True,
                            padding='max_length',
                            max_length=512,
                            return_tensors="pt"
                        )
                        input_ids_list = encoded_text['input_ids'].squeeze(0).tolist()
                        attention_mask_list = encoded_text['attention_mask'].squeeze(0).tolist()
                        
                        processed_data.append({
                            'input_ids': input_ids_list,
                            'attention_mask': attention_mask_list,
                            'labels': label_dict[dialect]
                        })
                        
    return processed_data

# %%
def collate_fn(batch):
    input_ids = [item['input_ids'] for item in batch]
    attention_masks = [item['attention_mask'] for item in batch]
    labels = [item['labels'] for item in batch]
    
    input_ids = pad_sequence([torch.tensor(seq) for seq in input_ids], batch_first=True, padding_value=tokenizer.pad_token_id)
    attention_masks = pad_sequence([torch.tensor(mask) for mask in attention_masks], batch_first=True, padding_value=0)
    
    labels = torch.tensor(labels)
    
    return {'input_ids': input_ids, 'attention_mask': attention_masks, 'labels': labels}

# %%
# so just the bibles data 
directory_paths = {
    'inb': '../language_resources/new_scraped_bible/inb',
    'qub': '../language_resources/new_scraped_bible/qub',
    'quf': '../language_resources/new_scraped_bible/quf',
    'quh': '../language_resources/new_scraped_bible/quh',
    'qul': '../language_resources/new_scraped_bible/qul',
    'qup': '../language_resources/new_scraped_bible/qup',
    'quw': '../language_resources/new_scraped_bible/quw',
    'quy': '../language_resources/new_scraped_bible/quy',
    'quz': '../language_resources/new_scraped_bible/quz', 
    'qvc': '../language_resources/new_scraped_bible/qvc',
    'qve': '../language_resources/new_scraped_bible/qve',  
    'qvi': '../language_resources/new_scraped_bible/qvi',
    'qvh': '../language_resources/new_scraped_bible/qvh',
    'qvm': '../language_resources/new_scraped_bible/qvm',
    'qvn': '../language_resources/new_scraped_bible/qvn',
    'qvo': '../language_resources/new_scraped_bible/qvo',
    'qvs': '../language_resources/new_scraped_bible/qvs',
    'qvw': '../language_resources/new_scraped_bible/qvw',
    'qvz': '../language_resources/new_scraped_bible/qvz',
    'qwh': '../language_resources/new_scraped_bible/qwh',
    'qxl': '../language_resources/new_scraped_bible/qxl',
    'qxh': '../language_resources/new_scraped_bible/qxh',
    'qxn': '../language_resources/new_scraped_bible/qxn',
    'qxo': '../language_resources/new_scraped_bible/qxo',
    'qxr': '../language_resources/new_scraped_bible/qxr'
}


# go through loading & processing
processed_data = load_and_preprocess(directory_paths)
# Out:
# dialect: inb
# filename: INBWBT_1JN.txt
# document is in 11 chunks
# filename: INBWBT_3JN.txt
# document is in 2 chunks
# filename: INBWBT_2TH.txt
# document is in 5 chunks
# filename: INBWBT_2TI.txt
# document is in 9 chunks
# filename: INBWBT_COL.txt
# document is in 10 chunks
# filename: INBWBT_1PE.txt
# document is in 13 chunks
# filename: INBWBT_HEB.txt
# document is in 34 chunks
# filename: INBWBT_2JN.txt
# document is in 1 chunks
# filename: INBWBT_EPH.txt
# document is in 14 chunks
# filename: INBWBT_MRK.txt
# document is in 59 chunks
# filename: INBWBT_TIT.txt
# document is in 5 chunks
# filename: INBWBT_1TI.txt
# document is in 12 chunks
# filename: INBWBT_1TH.txt
# document is in 9 chunks
# filename: INBWBT_LUK.txt
# document is in 99 chunks
# filename: INBWBT_PHP.txt
# document is in 10 chunks
# filename: INBWBT_2PE.txt
# document is in 8 chunks
# filename: INBWBT_REV.txt
# document is in 50 chunks
# filename: INBWBT_JAS.txt
# document is in 12 chunks
# filename: INBWBT_JUD.txt
# document is in 4 chunks
# filename: INBWBT_1CO.txt
# document is in 43 chunks
# filename: INBWBT_PHM.txt
# document is in 2 chunks
# filename: INBWBT_MAT.txt
# document is in 96 chunks
# filename: INBWBT_ROM.txt
# document is in 46 chunks
# filename: INBWBT_ACT.txt
# document is in 99 chunks
# filename: INBWBT_GAL.txt
# document is in 15 chunks
# filename: INBWBT_2CO.txt
# document is in 29 chunks
# filename: INBWBT_JHN.txt
# document is in 74 chunks
# dialect: qub
# filename: QUBPBS_PHP.txt
# document is in 8 chunks
# filename: QUBPBS_LUK.txt
# document is in 84 chunks
# filename: QUBPBS_2PE.txt
# document is in 6 chunks
# filename: QUBPBS_REV.txt
# document is in 38 chunks
# filename: QUBPBS_2JN.txt
# document is in 1 chunks
# filename: QUBPBS_EPH.txt
# document is in 11 chunks
# filename: QUBPBS_1TI.txt
# document is in 10 chunks
# filename: QUBPBS_TIT.txt
# document is in 4 chunks
# filename: QUBPBS_MRK.txt
# document is in 47 chunks
# filename: QUBPBS_1TH.txt
# document is in 7 chunks
# filename: QUBPBS_HEB.txt
# document is in 28 chunks
# filename: QUBPBS_1PE.txt
# document is in 10 chunks
# filename: QUBPBS_1JN.txt
# document is in 9 chunks
# filename: QUBPBS_3JN.txt
# document is in 1 chunks
# filename: QUBPBS_2TH.txt
# document is in 4 chunks
# filename: QUBPBS_2TI.txt
# document is in 7 chunks
# filename: QUBPBS_COL.txt
# document is in 8 chunks
# filename: QUBPBS_ACT.txt
# document is in 73 chunks
# filename: QUBPBS_2CO.txt
# document is in 21 chunks
# filename: QUBPBS_GAL.txt
# document is in 12 chunks
# filename: QUBPBS_JHN.txt
# document is in 61 chunks
# filename: QUBPBS_MAT.txt
# document is in 79 chunks
# filename: QUBPBS_ROM.txt
# document is in 36 chunks
# filename: QUBPBS_JUD.txt
# document is in 3 chunks
# filename: QUBPBS_1CO.txt
# document is in 35 chunks
# filename: QUBPBS_PHM.txt
# document is in 2 chunks
# filename: QUBPBS_JAS.txt
# document is in 9 chunks
# dialect: quf
# filename: QUFLLB_2JN.txt
# document is in 2 chunks
# filename: QUFLLB_EPH.txt
# document is in 17 chunks
# filename: QUFLLB_MRK.txt
# document is in 60 chunks
# filename: QUFLLB_TIT.txt
# document is in 7 chunks
# filename: QUFLLB_1TI.txt
# document is in 14 chunks
# filename: QUFLLB_1TH.txt
# document is in 9 chunks
# filename: QUFLLB_LUK.txt
# document is in 99 chunks
# filename: QUFLLB_PHP.txt
# document is in 12 chunks
# filename: QUFLLB_2PE.txt
# document is in 9 chunks
# filename: QUFLLB_REV.txt
# document is in 54 chunks
# filename: QUFLLB_1JN.txt
# document is in 14 chunks
# filename: QUFLLB_3JN.txt
# document is in 2 chunks
# filename: QUFLLB_2TH.txt
# document is in 5 chunks
# filename: QUFLLB_2TI.txt
# document is in 11 chunks
# filename: QUFLLB_COL.txt
# document is in 10 chunks
# filename: QUFLLB_1PE.txt
# document is in 14 chunks
# filename: QUFLLB_HEB.txt
# document is in 33 chunks
# filename: QUFLLB_MAT.txt
# document is in 103 chunks
# filename: QUFLLB_ROM.txt
# document is in 51 chunks
# filename: QUFLLB_ACT.txt
# document is in 98 chunks
# filename: QUFLLB_GAL.txt
# document is in 19 chunks
# filename: QUFLLB_2CO.txt
# document is in 27 chunks
# filename: QUFLLB_JHN.txt
# document is in 75 chunks
# filename: QUFLLB_JAS.txt
# document is in 12 chunks
# filename: QUFLLB_JUD.txt
# document is in 5 chunks
# filename: QUFLLB_1CO.txt
# document is in 51 chunks
# filename: QUFLLB_PHM.txt
# document is in 3 chunks
# dialect: quh
# filename: QUHQUE_JAS.txt
# document is in 10 chunks
# filename: QUHQUE_JUD.txt
# document is in 3 chunks
# filename: QUHQUE_1CO.txt
# document is in 39 chunks
# filename: QUHQUE_PHM.txt
# document is in 2 chunks
# filename: QUHQUE_MAT.txt
# document is in 84 chunks
# filename: QUHQUE_ROM.txt
# document is in 39 chunks
# filename: QUHQUE_ACT.txt
# document is in 87 chunks
# filename: QUHQUE_GAL.txt
# document is in 14 chunks
# filename: QUHQUE_2CO.txt
# document is in 25 chunks
# filename: QUHQUE_JHN.txt
# document is in 69 chunks
# filename: QUHQUE_1JN.txt
# document is in 10 chunks
# filename: QUHQUE_3JN.txt
# document is in 2 chunks
# filename: QUHQUE_2TH.txt
# document is in 4 chunks
# filename: QUHQUE_2TI.txt
# document is in 8 chunks
# filename: QUHQUE_COL.txt
# document is in 9 chunks
# filename: QUHQUE_1PE.txt
# document is in 11 chunks
# filename: QUHQUE_HEB.txt
# document is in 30 chunks
# filename: QUHQUE_2JN.txt
# document is in 1 chunks
# filename: QUHQUE_EPH.txt
# document is in 13 chunks
# filename: QUHQUE_MRK.txt
# document is in 54 chunks
# filename: QUHQUE_1TI.txt
# document is in 11 chunks
# filename: QUHQUE_TIT.txt
# document is in 5 chunks
# filename: QUHQUE_1TH.txt
# document is in 8 chunks
# filename: QUHQUE_PHP.txt
# document is in 9 chunks
# filename: QUHQUE_LUK.txt
# document is in 87 chunks
# filename: QUHQUE_2PE.txt
# document is in 7 chunks
# filename: QUHQUE_REV.txt
# document is in 45 chunks
# dialect: qul
# filename: QULSBB_JAS.txt
# document is in 10 chunks
# filename: QULSBB_PHM.txt
# document is in 2 chunks
# filename: QULSBB_1CO.txt
# document is in 40 chunks
# filename: QULSBB_JUD.txt
# document is in 3 chunks
# filename: QULSBB_ROM.txt
# document is in 40 chunks
# filename: QULSBB_MAT.txt
# document is in 88 chunks
# filename: QULSBB_2CO.txt
# document is in 26 chunks
# filename: QULSBB_GAL.txt
# document is in 14 chunks
# filename: QULSBB_JHN.txt
# document is in 74 chunks
# filename: QULSBB_ACT.txt
# document is in 94 chunks
# filename: QULSBB_2TI.txt
# document is in 8 chunks
# filename: QULSBB_COL.txt
# document is in 9 chunks
# filename: QULSBB_3JN.txt
# document is in 2 chunks
# filename: QULSBB_2TH.txt
# document is in 4 chunks
# filename: QULSBB_1JN.txt
# document is in 9 chunks
# filename: QULSBB_HEB.txt
# document is in 30 chunks
# filename: QULSBB_1PE.txt
# document is in 11 chunks
# filename: QULSBB_1TH.txt
# document is in 8 chunks
# filename: QULSBB_TIT.txt
# document is in 5 chunks
# filename: QULSBB_1TI.txt
# document is in 11 chunks
# filename: QULSBB_MRK.txt
# document is in 56 chunks
# filename: QULSBB_EPH.txt
# document is in 13 chunks
# filename: QULSBB_2JN.txt
# document is in 1 chunks
# filename: QULSBB_REV.txt
# document is in 44 chunks
# filename: QULSBB_2PE.txt
# document is in 7 chunks
# filename: QULSBB_LUK.txt
# document is in 96 chunks
# filename: QULSBB_PHP.txt
# document is in 10 chunks
# dialect: qup
# filename: QUPTBL_1PE.txt
# document is in 16 chunks
# filename: QUPTBL_HEB.txt
# document is in 41 chunks
# filename: QUPTBL_2TI.txt
# document is in 10 chunks
# filename: QUPTBL_COL.txt
# document is in 12 chunks
# filename: QUPTBL_3JN.txt
# document is in 2 chunks
# filename: QUPTBL_2TH.txt
# document is in 6 chunks
# filename: QUPTBL_1JN.txt
# document is in 13 chunks
# filename: QUPTBL_REV.txt
# document is in 57 chunks
# filename: QUPTBL_2PE.txt
# document is in 10 chunks
# filename: QUPTBL_LUK.txt
# document is in 113 chunks
# filename: QUPTBL_PHP.txt
# document is in 12 chunks
# filename: QUPTBL_1TH.txt
# document is in 10 chunks
# filename: QUPTBL_MRK.txt
# document is in 69 chunks
# filename: QUPTBL_TIT.txt
# document is in 6 chunks
# filename: QUPTBL_1TI.txt
# document is in 14 chunks
# filename: QUPTBL_EPH.txt
# document is in 18 chunks
# filename: QUPTBL_2JN.txt
# document is in 2 chunks
# filename: QUPTBL_PHM.txt
# document is in 3 chunks
# filename: QUPTBL_1CO.txt
# document is in 54 chunks
# filename: QUPTBL_JUD.txt
# document is in 5 chunks
# filename: QUPTBL_JAS.txt
# document is in 14 chunks
# filename: QUPTBL_GAL.txt
# document is in 19 chunks
# filename: QUPTBL_2CO.txt
# document is in 31 chunks
# filename: QUPTBL_JHN.txt
# document is in 89 chunks
# filename: QUPTBL_ACT.txt
# document is in 107 chunks
# filename: QUPTBL_ROM.txt
# document is in 54 chunks
# filename: QUPTBL_MAT.txt
# document is in 114 chunks
# dialect: quw
# filename: QUWHLE_1PE.txt
# document is in 9 chunks
# filename: QUWHLE_HEB.txt
# document is in 24 chunks
# filename: QUWHLE_1JN.txt
# document is in 9 chunks
# filename: QUWHLE_COL.txt
# document is in 7 chunks
# filename: QUWHLE_2TI.txt
# document is in 6 chunks
# filename: QUWHLE_2TH.txt
# document is in 4 chunks
# filename: QUWHLE_3JN.txt
# document is in 1 chunks
# filename: QUWHLE_PHP.txt
# document is in 8 chunks
# filename: QUWHLE_LUK.txt
# document is in 82 chunks
# filename: QUWHLE_REV.txt
# document is in 38 chunks
# filename: QUWHLE_2PE.txt
# document is in 6 chunks
# filename: QUWHLE_EPH.txt
# document is in 11 chunks
# filename: QUWHLE_2JN.txt
# document is in 1 chunks
# filename: QUWHLE_1TH.txt
# document is in 7 chunks
# filename: QUWHLE_MRK.txt
# document is in 47 chunks
# filename: QUWHLE_1TI.txt
# document is in 9 chunks
# filename: QUWHLE_TIT.txt
# document is in 4 chunks
# filename: QUWHLE_JUD.txt
# document is in 3 chunks
# filename: QUWHLE_PHM.txt
# document is in 2 chunks
# filename: QUWHLE_1CO.txt
# document is in 32 chunks
# filename: QUWHLE_JAS.txt
# document is in 9 chunks
# filename: QUWHLE_JHN.txt
# document is in 62 chunks
# filename: QUWHLE_GAL.txt
# document is in 11 chunks
# filename: QUWHLE_2CO.txt
# document is in 21 chunks
# filename: QUWHLE_ACT.txt
# document is in 76 chunks
# filename: QUWHLE_ROM.txt
# document is in 32 chunks
# filename: QUWHLE_MAT.txt
# document is in 76 chunks
# dialect: quy
# filename: QUYBSR_ACT.txt
# document is in 73 chunks
# filename: QUYBSP_HAG.txt
# document is in 4 chunks
# filename: QUYSBU_1PE.txt
# document is in 9 chunks
# filename: QUYSBU_HEB.txt
# document is in 24 chunks
# filename: QUYBSP_JON.txt
# document is in 4 chunks
# filename: QUYBSP_ZEP.txt
# document is in 5 chunks
# filename: QUYBSR_GAL.txt
# document is in 11 chunks
# filename: QUYBSR_2CO.txt
# document is in 18 chunks
# filename: QUYBSP_1CH.txt
# document is in 62 chunks
# filename: QUYBSR_JHN.txt
# document is in 55 chunks
# filename: QUYBSP_PSA.txt
# document is in 116 chunks
# filename: QUYBSP_ISA.txt
# document is in 104 chunks
# filename: QUYBSP_JOL.txt
# document is in 6 chunks
# filename: QUYSBU_2TI.txt
# document is in 6 chunks
# filename: QUYSBU_COL.txt
# document is in 7 chunks
# filename: QUYSBU_3JN.txt
# document is in 1 chunks
# filename: QUYBSP_2SA.txt
# document is in 57 chunks
# filename: QUYSBU_2TH.txt
# document is in 3 chunks
# filename: QUYBSR_MAT.txt
# document is in 68 chunks
# filename: QUYBSP_HAB.txt
# document is in 5 chunks
# filename: QUYBSP_ZEC.txt
# document is in 19 chunks
# filename: QUYSBU_1JN.txt
# document is in 8 chunks
# filename: QUYBSP_DAN.txt
# document is in 35 chunks
# filename: QUYBSR_ROM.txt
# document is in 30 chunks
# filename: QUYBSP_2CH.txt
# document is in 77 chunks
# filename: QUYBSR_1CO.txt
# document is in 29 chunks
# filename: QUYSBU_REV.txt
# document is in 42 chunks
# filename: QUYBSR_PHM.txt
# document is in 2 chunks
# filename: QUYBSP_AMO.txt
# document is in 12 chunks
# filename: QUYSBU_2PE.txt
# document is in 5 chunks
# filename: QUYSBU_PHP.txt
# document is in 7 chunks
# filename: QUYSBU_LUK.txt
# document is in 84 chunks
# filename: QUYBSP_DEU.txt
# document is in 72 chunks
# filename: QUYBSP_NEH.txt
# document is in 31 chunks
# filename: QUYBSP_RUT.txt
# document is in 7 chunks
# filename: QUYBSP_ECC.txt
# document is in 16 chunks
# filename: QUYBSR_JUD.txt
# document is in 3 chunks
# filename: QUYBSP_EZR.txt
# document is in 22 chunks
# filename: QUYSBU_1TH.txt
# document is in 6 chunks
# filename: QUYBSP_1SA.txt
# document is in 70 chunks
# filename: QUYSBU_MRK.txt
# document is in 55 chunks
# filename: QUYSBU_1TI.txt
# document is in 9 chunks
# filename: QUYSBU_TIT.txt
# document is in 4 chunks
# filename: QUYBSR_JAS.txt
# document is in 8 chunks
# filename: QUYSBU_EPH.txt
# document is in 10 chunks
# filename: QUYBSP_EXO.txt
# document is in 90 chunks
# filename: QUYSBU_2JN.txt
# document is in 1 chunks
# filename: QUYSBU_PHM.txt
# document is in 1 chunks
# filename: QUYBSP_LEV.txt
# document is in 65 chunks
# filename: QUYBSR_2PE.txt
# document is in 5 chunks
# filename: QUYSBU_1CO.txt
# document is in 30 chunks
# filename: QUYBSP_1KI.txt
# document is in 69 chunks
# filename: QUYBSR_REV.txt
# document is in 37 chunks
# filename: QUYBSP_EZK.txt
# document is in 108 chunks
# filename: QUYSBU_JUD.txt
# document is in 3 chunks
# filename: QUYBSR_PHP.txt
# document is in 7 chunks
# filename: QUYBSP_JER.txt
# document is in 116 chunks
# filename: QUYBSR_LUK.txt
# document is in 72 chunks
# filename: QUYBSR_MRK.txt
# document is in 44 chunks
# filename: QUYBSR_1TI.txt
# document is in 8 chunks
# filename: QUYBSR_TIT.txt
# document is in 4 chunks
# filename: QUYSBU_JAS.txt
# document is in 8 chunks
# filename: QUYBSP_OBA.txt
# document is in 2 chunks
# filename: QUYBSR_1TH.txt
# document is in 6 chunks
# filename: QUYBSR_2JN.txt
# document is in 1 chunks
# filename: QUYBSP_MAL.txt
# document is in 6 chunks
# filename: QUYBSR_EPH.txt
# document is in 10 chunks
# filename: QUYBSP_JDG.txt
# document is in 53 chunks
# filename: QUYSBU_GAL.txt
# document is in 12 chunks
# filename: QUYBSP_2KI.txt
# document is in 67 chunks
# filename: QUYBSP_NUM.txt
# document is in 85 chunks
# filename: QUYSBU_2CO.txt
# document is in 18 chunks
# filename: QUYSBU_JHN.txt
# document is in 70 chunks
# filename: QUYSBU_ACT.txt
# document is in 85 chunks
# filename: QUYBSP_HOS.txt
# document is in 15 chunks
# filename: QUYBSR_1PE.txt
# document is in 8 chunks
# filename: QUYBSR_HEB.txt
# document is in 22 chunks
# filename: QUYBSP_JOS.txt
# document is in 52 chunks
# filename: QUYBSP_MIC.txt
# document is in 9 chunks
# filename: QUYBSP_PRO.txt
# document is in 46 chunks
# filename: QUYBSR_3JN.txt
# document is in 1 chunks
# filename: QUYBSP_SNG.txt
# document is in 8 chunks
# filename: QUYBSR_2TH.txt
# document is in 3 chunks
# filename: QUYBSR_2TI.txt
# document is in 6 chunks
# filename: QUYBSR_COL.txt
# document is in 7 chunks
# filename: QUYBSP_GEN.txt
# document is in 103 chunks
# filename: QUYBSP_LAM.txt
# document is in 9 chunks
# filename: QUYBSP_NAM.txt
# document is in 4 chunks
# filename: QUYBSP_EST.txt
# document is in 16 chunks
# filename: QUYSBU_ROM.txt
# document is in 34 chunks
# filename: QUYBSP_JOB.txt
# document is in 51 chunks
# filename: QUYSBU_MAT.txt
# document is in 82 chunks
# filename: QUYBSR_1JN.txt
# document is in 8 chunks
# dialect: quz
# filename: QUZBIV_1PE.txt
# document is in 10 chunks
# filename: QUZBIV_HEB.txt
# document is in 27 chunks
# filename: QUZPBS_1CO.txt
# document is in 32 chunks
# filename: QUZPBS_2SA.txt
# document is in 55 chunks
# filename: QUZPBS_PHM.txt
# document is in 2 chunks
# filename: QUZPBS_ZEC.txt
# document is in 18 chunks
# filename: QUZPBS_HAB.txt
# document is in 5 chunks
# filename: QUZPBS_JUD.txt
# document is in 3 chunks
# filename: QUZPBS_DAN.txt
# document is in 33 chunks
# filename: QUZBIV_COL.txt
# document is in 8 chunks
# filename: QUZBIV_2TI.txt
# document is in 7 chunks
# filename: QUZPBS_JON.txt
# document is in 4 chunks
# filename: QUZPBS_HAG.txt
# document is in 4 chunks
# filename: QUZPBS_1CH.txt
# document is in 62 chunks
# filename: QUZPBS_JAS.txt
# document is in 8 chunks
# filename: QUZPBS_ZEP.txt
# document is in 5 chunks
# filename: QUZBIV_2TH.txt
# document is in 4 chunks
# filename: QUZPBS_PSA.txt
# document is in 114 chunks
# filename: QUZBIV_3JN.txt
# document is in 1 chunks
# filename: QUZBIV_1JN.txt
# document is in 9 chunks
# filename: QUZPBS_ISA.txt
# document is in 107 chunks
# filename: QUZPBS_JOL.txt
# document is in 7 chunks
# filename: QUZPBS_EZR.txt
# document is in 21 chunks
# filename: QUZPBS_1SA.txt
# document is in 68 chunks
# filename: QUZBIV_REV.txt
# document is in 44 chunks
# filename: QUZPBS_ACT.txt
# document is in 74 chunks
# filename: QUZPBS_JHN.txt
# document is in 58 chunks
# filename: QUZBIV_2PE.txt
# document is in 6 chunks
# filename: QUZPBS_2CO.txt
# document is in 20 chunks
# filename: QUZPBS_GAL.txt
# document is in 11 chunks
# filename: QUZBIV_LUK.txt
# document is in 88 chunks
# filename: QUZBIV_PHP.txt
# document is in 8 chunks
# filename: QUZPBS_EXO.txt
# document is in 87 chunks
# filename: QUZBIV_1TH.txt
# document is in 7 chunks
# filename: QUZPBS_2CH.txt
# document is in 78 chunks
# filename: QUZPBS_AMO.txt
# document is in 13 chunks
# filename: QUZBIV_MRK.txt
# document is in 53 chunks
# filename: QUZBIV_TIT.txt
# document is in 4 chunks
# filename: QUZBIV_1TI.txt
# document is in 9 chunks
# filename: QUZPBS_MAT.txt
# document is in 71 chunks
# filename: QUZPBS_DEU.txt
# document is in 74 chunks
# filename: QUZBIV_EPH.txt
# document is in 12 chunks
# filename: QUZBIV_2JN.txt
# document is in 1 chunks
# filename: QUZPBS_ECC.txt
# document is in 16 chunks
# filename: QUZPBS_ROM.txt
# document is in 32 chunks
# filename: QUZPBS_NEH.txt
# document is in 31 chunks
# filename: QUZPBS_RUT.txt
# document is in 7 chunks
# filename: QUZBIV_PHM.txt
# document is in 2 chunks
# filename: QUZPBS_OBA.txt
# document is in 2 chunks
# filename: QUZPBS_HEB.txt
# document is in 23 chunks
# filename: QUZPBS_1PE.txt
# document is in 9 chunks
# filename: QUZBIV_1CO.txt
# document is in 35 chunks
# filename: QUZBIV_JUD.txt
# document is in 3 chunks
# filename: QUZPBS_MAL.txt
# document is in 6 chunks
# filename: QUZPBS_JDG.txt
# document is in 52 chunks
# filename: QUZPBS_2TH.txt
# document is in 4 chunks
# filename: QUZBIV_JAS.txt
# document is in 9 chunks
# filename: QUZPBS_LEV.txt
# document is in 62 chunks
# filename: QUZPBS_3JN.txt
# document is in 1 chunks
# filename: QUZPBS_1KI.txt
# document is in 70 chunks
# filename: QUZPBS_COL.txt
# document is in 7 chunks
# filename: QUZPBS_2TI.txt
# document is in 6 chunks
# filename: QUZPBS_EZK.txt
# document is in 109 chunks
# filename: QUZPBS_1JN.txt
# document is in 8 chunks
# filename: QUZPBS_JER.txt
# document is in 118 chunks
# filename: QUZBIV_JHN.txt
# document is in 67 chunks
# filename: QUZPBS_2PE.txt
# document is in 6 chunks
# filename: QUZPBS_SNG.txt
# document is in 8 chunks
# filename: QUZBIV_GAL.txt
# document is in 12 chunks
# filename: QUZBIV_2CO.txt
# document is in 22 chunks
# filename: QUZPBS_REV.txt
# document is in 37 chunks
# filename: QUZBIV_ACT.txt
# document is in 83 chunks
# filename: QUZPBS_LAM.txt
# document is in 10 chunks
# filename: QUZPBS_GEN.txt
# document is in 103 chunks
# filename: QUZPBS_NAM.txt
# document is in 4 chunks
# filename: QUZPBS_EST.txt
# document is in 16 chunks
# filename: QUZPBS_JOB.txt
# document is in 52 chunks
# filename: QUZPBS_LUK.txt
# document is in 74 chunks
# filename: QUZPBS_PHP.txt
# document is in 8 chunks
# filename: QUZPBS_NUM.txt
# document is in 89 chunks
# filename: QUZPBS_2KI.txt
# document is in 68 chunks
# filename: QUZPBS_TIT.txt
# document is in 4 chunks
# filename: QUZPBS_1TI.txt
# document is in 9 chunks
# filename: QUZPBS_MRK.txt
# document is in 44 chunks
# filename: QUZPBS_HOS.txt
# document is in 16 chunks
# filename: QUZPBS_1TH.txt
# document is in 6 chunks
# filename: QUZPBS_2JN.txt
# document is in 1 chunks
# filename: QUZPBS_JOS.txt
# document is in 51 chunks
# filename: QUZBIV_ROM.txt
# document is in 36 chunks
# filename: QUZPBS_MIC.txt
# document is in 9 chunks
# filename: QUZPBS_PRO.txt
# document is in 44 chunks
# filename: QUZBIV_MAT.txt
# document is in 83 chunks
# filename: QUZPBS_EPH.txt
# document is in 10 chunks
# dialect: qvc
# filename: QVCTBL_1TH.txt
# document is in 8 chunks
# filename: QVCTBL_1TI.txt
# document is in 12 chunks
# filename: QVCTBL_TIT.txt
# document is in 5 chunks
# filename: QVCTBL_MRK.txt
# document is in 64 chunks
# filename: QVCTBL_EPH.txt
# document is in 15 chunks
# filename: QVCTBL_2JN.txt
# document is in 1 chunks
# filename: QVCTBL_REV.txt
# document is in 57 chunks
# filename: QVCTBL_2PE.txt
# document is in 7 chunks
# filename: QVCTBL_PHP.txt
# document is in 10 chunks
# filename: QVCTBL_LUK.txt
# document is in 106 chunks
# filename: QVCTBL_COL.txt
# document is in 10 chunks
# filename: QVCTBL_2TI.txt
# document is in 9 chunks
# filename: QVCTBL_2TH.txt
# document is in 5 chunks
# filename: QVCTBL_3JN.txt
# document is in 2 chunks
# filename: QVCTBL_1JN.txt
# document is in 11 chunks
# filename: QVCTBL_HEB.txt
# document is in 37 chunks
# filename: QVCTBL_1PE.txt
# document is in 11 chunks
# filename: QVCTBL_ROM.txt
# document is in 49 chunks
# filename: QVCTBL_MAT.txt
# document is in 105 chunks
# filename: QVCTBL_JHN.txt
# document is in 81 chunks
# filename: QVCTBL_2CO.txt
# document is in 29 chunks
# filename: QVCTBL_GAL.txt
# document is in 16 chunks
# filename: QVCTBL_ACT.txt
# document is in 102 chunks
# filename: QVCTBL_JAS.txt
# document is in 11 chunks
# filename: QVCTBL_PHM.txt
# document is in 2 chunks
# filename: QVCTBL_1CO.txt
# document is in 47 chunks
# filename: QVCTBL_JUD.txt
# document is in 4 chunks
# dialect: qve
# filename: QVETBL_JAS.txt
# document is in 11 chunks
# filename: QVETBL_JUD.txt
# document is in 4 chunks
# filename: QVETBL_1CO.txt
# document is in 48 chunks
# filename: QVETBL_PHM.txt
# document is in 3 chunks
# filename: QVETBL_MAT.txt
# document is in 106 chunks
# filename: QVETBL_ROM.txt
# document is in 49 chunks
# filename: QVETBL_ACT.txt
# document is in 113 chunks
# filename: QVETBL_JHN.txt
# document is in 82 chunks
# filename: QVETBL_2CO.txt
# document is in 31 chunks
# filename: QVETBL_GAL.txt
# document is in 18 chunks
# filename: QVETBL_1JN.txt
# document is in 11 chunks
# filename: QVETBL_2TH.txt
# document is in 5 chunks
# filename: QVETBL_3JN.txt
# document is in 2 chunks
# filename: QVETBL_COL.txt
# document is in 11 chunks
# filename: QVETBL_2TI.txt
# document is in 9 chunks
# filename: QVETBL_HEB.txt
# document is in 40 chunks
# filename: QVETBL_1PE.txt
# document is in 13 chunks
# filename: QVETBL_2JN.txt
# document is in 2 chunks
# filename: QVETBL_EPH.txt
# document is in 16 chunks
# filename: QVETBL_TIT.txt
# document is in 6 chunks
# filename: QVETBL_1TI.txt
# document is in 13 chunks
# filename: QVETBL_MRK.txt
# document is in 65 chunks
# filename: QVETBL_1TH.txt
# document is in 10 chunks
# filename: QVETBL_LUK.txt
# document is in 108 chunks
# filename: QVETBL_PHP.txt
# document is in 11 chunks
# filename: QVETBL_2PE.txt
# document is in 8 chunks
# filename: QVETBL_REV.txt
# document is in 55 chunks
# dialect: qvi
# filename: QVIIHB_1TI.txt
# document is in 11 chunks
# filename: QVIIHB_TIT.txt
# document is in 5 chunks
# filename: QVIIHB_MRK.txt
# document is in 62 chunks
# filename: QVIIHB_1TH.txt
# document is in 8 chunks
# filename: QVIIHB_2JN.txt
# document is in 1 chunks
# filename: QVIIHB_EPH.txt
# document is in 13 chunks
# filename: QVIIHB_2PE.txt
# document is in 7 chunks
# filename: QVIIHB_REV.txt
# document is in 46 chunks
# filename: QVIIHB_PHP.txt
# document is in 9 chunks
# filename: QVIIHB_LUK.txt
# document is in 105 chunks
# filename: QVIIHB_2TH.txt
# document is in 5 chunks
# filename: QVIIHB_3JN.txt
# document is in 2 chunks
# filename: QVIIHB_COL.txt
# document is in 9 chunks
# filename: QVIIHB_2TI.txt
# document is in 8 chunks
# filename: QVIIHB_1JN.txt
# document is in 10 chunks
# filename: QVIIHB_HEB.txt
# document is in 29 chunks
# filename: QVIIHB_1PE.txt
# document is in 11 chunks
# filename: QVIIHB_MAT.txt
# document is in 98 chunks
# filename: QVIIHB_ROM.txt
# document is in 40 chunks
# filename: QVIIHB_ACT.txt
# document is in 95 chunks
# filename: QVIIHB_JHN.txt
# document is in 77 chunks
# filename: QVIIHB_2CO.txt
# document is in 24 chunks
# filename: QVIIHB_GAL.txt
# document is in 13 chunks
# filename: QVIIHB_JAS.txt
# document is in 10 chunks
# filename: QVIIHB_1CO.txt
# document is in 38 chunks
# filename: QVIIHB_PHM.txt
# document is in 2 chunks
# filename: QVIIHB_JUD.txt
# document is in 3 chunks
# dialect: qvh
# filename: QVHLLB_MAT.txt
# document is in 74 chunks
# filename: QVHLLB_ROM.txt
# document is in 34 chunks
# filename: QVHLLB_ACT.txt
# document is in 75 chunks
# filename: QVHLLB_JHN.txt
# document is in 59 chunks
# filename: QVHLLB_2CO.txt
# document is in 21 chunks
# filename: QVHLLB_GAL.txt
# document is in 12 chunks
# filename: QVHLLB_JAS.txt
# document is in 9 chunks
# filename: QVHLLB_JUD.txt
# document is in 3 chunks
# filename: QVHLLB_1CO.txt
# document is in 34 chunks
# filename: QVHLLB_PHM.txt
# document is in 2 chunks
# filename: QVHLLB_2JN.txt
# document is in 1 chunks
# filename: QVHLLB_EPH.txt
# document is in 11 chunks
# filename: QVHLLB_1TI.txt
# document is in 9 chunks
# filename: QVHLLB_TIT.txt
# document is in 4 chunks
# filename: QVHLLB_MRK.txt
# document is in 45 chunks
# filename: QVHLLB_1TH.txt
# document is in 7 chunks
# filename: QVHLLB_PHP.txt
# document is in 7 chunks
# filename: QVHLLB_LUK.txt
# document is in 77 chunks
# filename: QVHLLB_2PE.txt
# document is in 6 chunks
# filename: QVHLLB_REV.txt
# document is in 39 chunks
# filename: QVHLLB_1JN.txt
# document is in 9 chunks
# filename: QVHLLB_2TH.txt
# document is in 4 chunks
# filename: QVHLLB_3JN.txt
# document is in 1 chunks
# filename: QVHLLB_COL.txt
# document is in 7 chunks
# filename: QVHLLB_2TI.txt
# document is in 7 chunks
# filename: QVHLLB_HEB.txt
# document is in 26 chunks
# filename: QVHLLB_1PE.txt
# document is in 9 chunks
# dialect: qvm
# filename: QVMTBL_JUD.txt
# document is in 3 chunks
# filename: QVMTBL_1CO.txt
# document is in 37 chunks
# filename: QVMTBL_PHM.txt
# document is in 2 chunks
# filename: QVMTBL_JAS.txt
# document is in 9 chunks
# filename: QVMTBL_ACT.txt
# document is in 87 chunks
# filename: QVMTBL_JHN.txt
# document is in 66 chunks
# filename: QVMTBL_GAL.txt
# document is in 14 chunks
# filename: QVMTBL_2CO.txt
# document is in 22 chunks
# filename: QVMTBL_MAT.txt
# document is in 88 chunks
# filename: QVMTBL_ROM.txt
# document is in 39 chunks
# filename: QVMTBL_1PE.txt
# document is in 10 chunks
# filename: QVMTBL_HEB.txt
# document is in 28 chunks
# filename: QVMTBL_1JN.txt
# document is in 10 chunks
# filename: QVMTBL_2TH.txt
# document is in 4 chunks
# filename: QVMTBL_3JN.txt
# document is in 1 chunks
# filename: QVMTBL_COL.txt
# document is in 8 chunks
# filename: QVMTBL_2TI.txt
# document is in 8 chunks
# filename: QVMTBL_PHP.txt
# document is in 8 chunks
# filename: QVMTBL_LUK.txt
# document is in 88 chunks
# filename: QVMTBL_2PE.txt
# document is in 6 chunks
# filename: QVMTBL_REV.txt
# document is in 42 chunks
# filename: QVMTBL_2JN.txt
# document is in 1 chunks
# filename: QVMTBL_EPH.txt
# document is in 12 chunks
# filename: QVMTBL_MRK.txt
# document is in 53 chunks
# filename: QVMTBL_1TI.txt
# document is in 10 chunks
# filename: QVMTBL_TIT.txt
# document is in 5 chunks
# filename: QVMTBL_1TH.txt
# document is in 7 chunks
# dialect: qvn
# filename: QVNLLB_COL.txt
# document is in 8 chunks
# filename: QVNLLB_2TI.txt
# document is in 9 chunks
# filename: QVNLLB_2TH.txt
# document is in 5 chunks
# filename: QVNLLB_3JN.txt
# document is in 1 chunks
# filename: QVNLLB_1JN.txt
# document is in 9 chunks
# filename: QVNLLB_HEB.txt
# document is in 27 chunks
# filename: QVNLLB_1PE.txt
# document is in 10 chunks
# filename: QVNLLB_1TH.txt
# document is in 9 chunks
# filename: QVNLLB_TIT.txt
# document is in 4 chunks
# filename: QVNLLB_1TI.txt
# document is in 13 chunks
# filename: QVNLLB_MRK.txt
# document is in 53 chunks
# filename: QVNLLB_EPH.txt
# document is in 12 chunks
# filename: QVNLLB_2JN.txt
# document is in 1 chunks
# filename: QVNLLB_REV.txt
# document is in 45 chunks
# filename: QVNLLB_2PE.txt
# document is in 6 chunks
# filename: QVNLLB_LUK.txt
# document is in 89 chunks
# filename: QVNLLB_PHP.txt
# document is in 11 chunks
# filename: QVNLLB_JAS.txt
# document is in 10 chunks
# filename: QVNLLB_PHM.txt
# document is in 2 chunks
# filename: QVNLLB_1CO.txt
# document is in 47 chunks
# filename: QVNLLB_JUD.txt
# document is in 3 chunks
# filename: QVNLLB_ROM.txt
# document is in 38 chunks
# filename: QVNLLB_MAT.txt
# document is in 90 chunks
# filename: QVNLLB_JHN.txt
# document is in 66 chunks
# filename: QVNLLB_2CO.txt
# document is in 29 chunks
# filename: QVNLLB_GAL.txt
# document is in 13 chunks
# filename: QVNLLB_ACT.txt
# document is in 93 chunks
# dialect: qvo
# filename: QVOVAA_1JN.txt
# document is in 9 chunks
# filename: QVOVAA_2TI.txt
# document is in 7 chunks
# filename: QVOVAA_COL.txt
# document is in 8 chunks
# filename: QVOVAA_3JN.txt
# document is in 1 chunks
# filename: QVOVAA_2TH.txt
# document is in 4 chunks
# filename: QVOVAA_HEB.txt
# document is in 26 chunks
# filename: QVOVAA_1PE.txt
# document is in 10 chunks
# filename: QVOVAA_EPH.txt
# document is in 11 chunks
# filename: QVOVAA_2JN.txt
# document is in 1 chunks
# filename: QVOVAA_1TH.txt
# document is in 7 chunks
# filename: QVOVAA_TIT.txt
# document is in 4 chunks
# filename: QVOVAA_1TI.txt
# document is in 9 chunks
# filename: QVOVAA_MRK.txt
# document is in 44 chunks
# filename: QVOVAA_LUK.txt
# document is in 78 chunks
# filename: QVOVAA_PHP.txt
# document is in 8 chunks
# filename: QVOVAA_REV.txt
# document is in 38 chunks
# filename: QVOVAA_2PE.txt
# document is in 6 chunks
# filename: QVOVAA_JAS.txt
# document is in 9 chunks
# filename: QVOVAA_JUD.txt
# document is in 3 chunks
# filename: QVOVAA_PHM.txt
# document is in 2 chunks
# filename: QVOVAA_1CO.txt
# document is in 34 chunks
# filename: QVOVAA_ROM.txt
# document is in 32 chunks
# filename: QVOVAA_MAT.txt
# document is in 73 chunks
# filename: QVOVAA_2CO.txt
# document is in 22 chunks
# filename: QVOVAA_GAL.txt
# document is in 12 chunks
# filename: QVOVAA_JHN.txt
# document is in 60 chunks
# filename: QVOVAA_ACT.txt
# document is in 73 chunks
# dialect: qvs
# filename: QVSTBL_JUD.txt
# document is in 4 chunks
# filename: QVSTBL_PHM.txt
# document is in 2 chunks
# filename: QVSTBL_1CO.txt
# document is in 44 chunks
# filename: QVSTBL_JAS.txt
# document is in 11 chunks
# filename: QVSTBL_GAL.txt
# document is in 15 chunks
# filename: QVSTBL_2CO.txt
# document is in 27 chunks
# filename: QVSTBL_JHN.txt
# document is in 80 chunks
# filename: QVSTBL_ACT.txt
# document is in 95 chunks
# filename: QVSTBL_ROM.txt
# document is in 41 chunks
# filename: QVSTBL_MAT.txt
# document is in 100 chunks
# filename: QVSTBL_1PE.txt
# document is in 13 chunks
# filename: QVSTBL_HEB.txt
# document is in 34 chunks
# filename: QVSTBL_1JN.txt
# document is in 11 chunks
# filename: QVSTBL_2TI.txt
# document is in 8 chunks
# filename: QVSTBL_COL.txt
# document is in 9 chunks
# filename: QVSTBL_3JN.txt
# document is in 2 chunks
# filename: QVSTBL_2TH.txt
# document is in 5 chunks
# filename: QVSTBL_PHP.txt
# document is in 9 chunks
# filename: QVSTBL_LUK.txt
# document is in 110 chunks
# filename: QVSTBL_REV.txt
# document is in 54 chunks
# filename: QVSTBL_2PE.txt
# document is in 8 chunks
# filename: QVSTBL_EPH.txt
# document is in 14 chunks
# filename: QVSTBL_2JN.txt
# document is in 1 chunks
# filename: QVSTBL_1TH.txt
# document is in 8 chunks
# filename: QVSTBL_MRK.txt
# document is in 58 chunks
# filename: QVSTBL_1TI.txt
# document is in 12 chunks
# filename: QVSTBL_TIT.txt
# document is in 5 chunks
# dialect: qvw
# filename: QVWTBL_1PE.txt
# document is in 9 chunks
# filename: QVWTBL_HEB.txt
# document is in 23 chunks
# filename: QVWTBL_2TI.txt
# document is in 6 chunks
# filename: QVWTBL_COL.txt
# document is in 7 chunks
# filename: QVWTBL_3JN.txt
# document is in 1 chunks
# filename: QVWTBL_2TH.txt
# document is in 3 chunks
# filename: QVWTBL_1JN.txt
# document is in 8 chunks
# filename: QVWTBL_REV.txt
# document is in 40 chunks
# filename: QVWTBL_2PE.txt
# document is in 5 chunks
# filename: QVWTBL_LUK.txt
# document is in 82 chunks
# filename: QVWTBL_PHP.txt
# document is in 7 chunks
# filename: QVWTBL_1TH.txt
# document is in 6 chunks
# filename: QVWTBL_MRK.txt
# document is in 44 chunks
# filename: QVWTBL_TIT.txt
# document is in 4 chunks
# filename: QVWTBL_1TI.txt
# document is in 8 chunks
# filename: QVWTBL_EPH.txt
# document is in 10 chunks
# filename: QVWTBL_2JN.txt
# document is in 1 chunks
# filename: QVWTBL_PHM.txt
# document is in 2 chunks
# filename: QVWTBL_1CO.txt
# document is in 31 chunks
# filename: QVWTBL_JUD.txt
# document is in 3 chunks
# filename: QVWTBL_JAS.txt
# document is in 8 chunks
# filename: QVWTBL_GAL.txt
# document is in 11 chunks
# filename: QVWTBL_2CO.txt
# document is in 19 chunks
# filename: QVWTBL_JHN.txt
# document is in 56 chunks
# filename: QVWTBL_ACT.txt
# document is in 77 chunks
# filename: QVWTBL_ROM.txt
# document is in 33 chunks
# filename: QVWTBL_MAT.txt
# document is in 73 chunks
# dialect: qvz
# filename: QVZWBT_1PE.txt
# document is in 13 chunks
# filename: QVZWBT_HEB.txt
# document is in 33 chunks
# filename: QVZWBT_2TI.txt
# document is in 9 chunks
# filename: QVZWBT_COL.txt
# document is in 10 chunks
# filename: QVZWBT_3JN.txt
# document is in 2 chunks
# filename: QVZWBT_2TH.txt
# document is in 5 chunks
# filename: QVZWBT_1JN.txt
# document is in 11 chunks
# filename: QVZWBT_REV.txt
# document is in 52 chunks
# filename: QVZWBT_2PE.txt
# document is in 8 chunks
# filename: QVZWBT_PHP.txt
# document is in 10 chunks
# filename: QVZWBT_LUK.txt
# document is in 111 chunks
# filename: QVZWBT_1TH.txt
# document is in 8 chunks
# filename: QVZWBT_MRK.txt
# document is in 57 chunks
# filename: QVZWBT_1TI.txt
# document is in 13 chunks
# filename: QVZWBT_TIT.txt
# document is in 6 chunks
# filename: QVZWBT_EPH.txt
# document is in 15 chunks
# filename: QVZWBT_2JN.txt
# document is in 2 chunks
# filename: QVZWBT_PHM.txt
# document is in 3 chunks
# filename: QVZWBT_1CO.txt
# document is in 46 chunks
# filename: QVZWBT_JUD.txt
# document is in 4 chunks
# filename: QVZWBT_JAS.txt
# document is in 12 chunks
# filename: QVZWBT_GAL.txt
# document is in 14 chunks
# filename: QVZWBT_2CO.txt
# document is in 29 chunks
# filename: QVZWBT_JHN.txt
# document is in 78 chunks
# filename: QVZWBT_ACT.txt
# document is in 105 chunks
# filename: QVZWBT_ROM.txt
# document is in 43 chunks
# filename: QVZWBT_MAT.txt
# document is in 99 chunks
# dialect: qwh
# filename: QWHWBT_1PE.txt
# document is in 9 chunks
# filename: QWHWBT_HEB.txt
# document is in 26 chunks
# filename: QWHLLB_REV.txt
# document is in 43 chunks
# filename: QWHLLB_2PE.txt
# document is in 6 chunks
# filename: QWHLLB_LUK.txt
# document is in 83 chunks
# filename: QWHLLB_PHP.txt
# document is in 9 chunks
# filename: QWHLLB_1TH.txt
# document is in 7 chunks
# filename: QWHWBT_COL.txt
# document is in 8 chunks
# filename: QWHWBT_2TI.txt
# document is in 7 chunks
# filename: QWHWBT_2TH.txt
# document is in 4 chunks
# filename: QWHLLB_MRK.txt
# document is in 50 chunks
# filename: QWHLLB_TIT.txt
# document is in 5 chunks
# filename: QWHLLB_1TI.txt
# document is in 10 chunks
# filename: QWHWBT_3JN.txt
# document is in 1 chunks
# filename: QWHWBT_1JN.txt
# document is in 9 chunks
# filename: QWHLLB_EPH.txt
# document is in 11 chunks
# filename: QWHLLB_2JN.txt
# document is in 1 chunks
# filename: QWHLLB_1PE.txt
# document is in 10 chunks
# filename: QWHLLB_HEB.txt
# document is in 27 chunks
# filename: QWHWBT_REV.txt
# document is in 39 chunks
# filename: QWHWBT_2PE.txt
# document is in 6 chunks
# filename: QWHWBT_LUK.txt
# document is in 77 chunks
# filename: QWHWBT_PHP.txt
# document is in 8 chunks
# filename: QWHWBT_1TH.txt
# document is in 7 chunks
# filename: QWHLLB_COL.txt
# document is in 8 chunks
# filename: QWHLLB_2TI.txt
# document is in 7 chunks
# filename: QWHLLB_2TH.txt
# document is in 4 chunks
# filename: QWHWBT_MRK.txt
# document is in 45 chunks
# filename: QWHWBT_TIT.txt
# document is in 4 chunks
# filename: QWHLLB_3JN.txt
# document is in 1 chunks
# filename: QWHWBT_1TI.txt
# document is in 10 chunks
# filename: QWHLLB_1JN.txt
# document is in 9 chunks
# filename: QWHWBT_EPH.txt
# document is in 11 chunks
# filename: QWHWBT_2JN.txt
# document is in 1 chunks
# filename: QWHLLB_JHN.txt
# document is in 64 chunks
# filename: QWHLLB_GAL.txt
# document is in 12 chunks
# filename: QWHWBT_PHM.txt
# document is in 2 chunks
# filename: QWHLLB_2CO.txt
# document is in 23 chunks
# filename: QWHWBT_1CO.txt
# document is in 34 chunks
# filename: QWHLLB_ACT.txt
# document is in 88 chunks
# filename: QWHWBT_JUD.txt
# document is in 3 chunks
# filename: QWHWBT_JAS.txt
# document is in 9 chunks
# filename: QWHLLB_ROM.txt
# document is in 37 chunks
# filename: QWHLLB_MAT.txt
# document is in 85 chunks
# filename: QWHWBT_JHN.txt
# document is in 58 chunks
# filename: QWHWBT_GAL.txt
# document is in 12 chunks
# filename: QWHLLB_PHM.txt
# document is in 2 chunks
# filename: QWHWBT_2CO.txt
# document is in 21 chunks
# filename: QWHLLB_1CO.txt
# document is in 37 chunks
# filename: QWHWBT_ACT.txt
# document is in 75 chunks
# filename: QWHLLB_JUD.txt
# document is in 3 chunks
# filename: QWHLLB_JAS.txt
# document is in 10 chunks
# filename: QWHWBT_ROM.txt
# document is in 34 chunks
# filename: QWHWBT_MAT.txt
# document is in 74 chunks
# dialect: qxl
# filename: QXLQSV_2JN.txt
# document is in 1 chunks
# filename: QXLQSV_EPH.txt
# document is in 12 chunks
# filename: QXLQSV_TIT.txt
# document is in 4 chunks
# filename: QXLQSV_1TI.txt
# document is in 10 chunks
# filename: QXLQSV_MRK.txt
# document is in 50 chunks
# filename: QXLQSV_1TH.txt
# document is in 7 chunks
# filename: QXLQSV_LUK.txt
# document is in 83 chunks
# filename: QXLQSV_PHP.txt
# document is in 8 chunks
# filename: QXLQSV_2PE.txt
# document is in 7 chunks
# filename: QXLQSV_REV.txt
# document is in 45 chunks
# filename: QXLQSV_1JN.txt
# document is in 9 chunks
# filename: QXLQSV_2TH.txt
# document is in 4 chunks
# filename: QXLQSV_3JN.txt
# document is in 1 chunks
# filename: QXLQSV_COL.txt
# document is in 8 chunks
# filename: QXLQSV_2TI.txt
# document is in 7 chunks
# filename: QXLQSV_HEB.txt
# document is in 27 chunks
# filename: QXLQSV_1PE.txt
# document is in 10 chunks
# filename: QXLQSV_MAT.txt
# document is in 85 chunks
# filename: QXLQSV_ROM.txt
# document is in 37 chunks
# filename: QXLQSV_ACT.txt
# document is in 80 chunks
# filename: QXLQSV_JHN.txt
# document is in 68 chunks
# filename: QXLQSV_2CO.txt
# document is in 22 chunks
# filename: QXLQSV_GAL.txt
# document is in 13 chunks
# filename: QXLQSV_JAS.txt
# document is in 10 chunks
# filename: QXLQSV_JUD.txt
# document is in 3 chunks
# filename: QXLQSV_1CO.txt
# document is in 34 chunks
# filename: QXLQSV_PHM.txt
# document is in 2 chunks
# dialect: qxh
# filename: QXHWBT_PHP.txt
# document is in 8 chunks
# filename: QXHWBT_LUK.txt
# document is in 79 chunks
# filename: QXHWBT_2PE.txt
# document is in 6 chunks
# filename: QXHWBT_REV.txt
# document is in 39 chunks
# filename: QXHWBT_2JN.txt
# document is in 1 chunks
# filename: QXHWBT_EPH.txt
# document is in 12 chunks
# filename: QXHWBT_MRK.txt
# document is in 44 chunks
# filename: QXHWBT_1TI.txt
# document is in 10 chunks
# filename: QXHWBT_TIT.txt
# document is in 4 chunks
# filename: QXHWBT_1TH.txt
# document is in 7 chunks
# filename: QXHWBT_1PE.txt
# document is in 9 chunks
# filename: QXHWBT_HEB.txt
# document is in 28 chunks
# filename: QXHWBT_1JN.txt
# document is in 9 chunks
# filename: QXHWBT_2TH.txt
# document is in 4 chunks
# filename: QXHWBT_3JN.txt
# document is in 1 chunks
# filename: QXHWBT_COL.txt
# document is in 8 chunks
# filename: QXHWBT_2TI.txt
# document is in 7 chunks
# filename: QXHWBT_ACT.txt
# document is in 77 chunks
# filename: QXHWBT_JHN.txt
# document is in 60 chunks
# filename: QXHWBT_GAL.txt
# document is in 12 chunks
# filename: QXHWBT_2CO.txt
# document is in 21 chunks
# filename: QXHWBT_MAT.txt
# document is in 77 chunks
# filename: QXHWBT_ROM.txt
# document is in 39 chunks
# filename: QXHWBT_JUD.txt
# document is in 3 chunks
# filename: QXHWBT_1CO.txt
# document is in 33 chunks
# filename: QXHWBT_PHM.txt
# document is in 2 chunks
# filename: QXHWBT_JAS.txt
# document is in 8 chunks
# dialect: qxn
# filename: QXNDPI_1SA.txt
# document is in 70 chunks
# filename: QXNDPI_EZR.txt
# document is in 24 chunks
# filename: QXNWBT_PHM.txt
# document is in 2 chunks
# filename: QXNWBT_1CO.txt
# document is in 46 chunks
# filename: QXNWBT_JUD.txt
# document is in 4 chunks
# filename: QXNDPI_EXO.txt
# document is in 94 chunks
# filename: QXNWBT_JAS.txt
# document is in 13 chunks
# filename: QXNDPI_2CH.txt
# document is in 83 chunks
# filename: QXNDPI_AMO.txt
# document is in 14 chunks
# filename: QXNDPI_DEU.txt
# document is in 72 chunks
# filename: QXNDPI_ECC.txt
# document is in 17 chunks
# filename: QXNDPI_RUT.txt
# document is in 7 chunks
# filename: QXNDPI_NEH.txt
# document is in 35 chunks
# filename: QXNWBT_JHN.txt
# document is in 73 chunks
# filename: QXNWBT_GAL.txt
# document is in 16 chunks
# filename: QXNWBT_2CO.txt
# document is in 32 chunks
# filename: QXNDPI_2SA.txt
# document is in 60 chunks
# filename: QXNWBT_ACT.txt
# document is in 95 chunks
# filename: QXNDPI_ZEC.txt
# document is in 20 chunks
# filename: QXNDPI_HAB.txt
# document is in 5 chunks
# filename: QXNDPI_DAN.txt
# document is in 35 chunks
# filename: QXNDPI_JON.txt
# document is in 4 chunks
# filename: QXNDPI_HAG.txt
# document is in 4 chunks
# filename: QXNDPI_PSA.txt
# document is in 130 chunks
# filename: QXNDPI_1CH.txt
# document is in 74 chunks
# filename: QXNDPI_ZEP.txt
# document is in 6 chunks
# filename: QXNDPI_ISA.txt
# document is in 110 chunks
# filename: QXNWBT_ROM.txt
# document is in 48 chunks
# filename: QXNWBT_MAT.txt
# document is in 90 chunks
# filename: QXNDPI_JOL.txt
# document is in 6 chunks
# filename: QXNWBT_1PE.txt
# document is in 12 chunks
# filename: QXNDPI_SNG.txt
# document is in 9 chunks
# filename: QXNWBT_HEB.txt
# document is in 36 chunks
# filename: QXNDPI_LAM.txt
# document is in 10 chunks
# filename: QXNDPI_GEN.txt
# document is in 112 chunks
# filename: QXNDPI_JOB.txt
# document is in 53 chunks
# filename: QXNDPI_EST.txt
# document is in 17 chunks
# filename: QXNDPI_NAM.txt
# document is in 5 chunks
# filename: QXNWBT_COL.txt
# document is in 10 chunks
# filename: QXNWBT_2TI.txt
# document is in 9 chunks
# filename: QXNDPI_2KI.txt
# document is in 71 chunks
# filename: QXNDPI_NUM.txt
# document is in 92 chunks
# filename: QXNWBT_2TH.txt
# document is in 6 chunks
# filename: QXNDPI_HOS.txt
# document is in 18 chunks
# filename: QXNWBT_3JN.txt
# document is in 2 chunks
# filename: QXNDPI_JOS.txt
# document is in 54 chunks
# filename: QXNWBT_1JN.txt
# document is in 12 chunks
# filename: QXNDPI_PRO.txt
# document is in 51 chunks
# filename: QXNDPI_MIC.txt
# document is in 10 chunks
# filename: QXNDPI_OBA.txt
# document is in 2 chunks
# filename: QXNWBT_REV.txt
# document is in 51 chunks
# filename: QXNWBT_2PE.txt
# document is in 8 chunks
# filename: QXNDPI_MAL.txt
# document is in 6 chunks
# filename: QXNWBT_LUK.txt
# document is in 92 chunks
# filename: QXNWBT_PHP.txt
# document is in 11 chunks
# filename: QXNDPI_JDG.txt
# document is in 54 chunks
# filename: QXNWBT_1TH.txt
# document is in 9 chunks
# filename: QXNDPI_LEV.txt
# document is in 64 chunks
# filename: QXNDPI_EZK.txt
# document is in 108 chunks
# filename: QXNWBT_MRK.txt
# document is in 55 chunks
# filename: QXNDPI_1KI.txt
# document is in 72 chunks
# filename: QXNWBT_TIT.txt
# document is in 5 chunks
# filename: QXNWBT_1TI.txt
# document is in 12 chunks
# filename: QXNWBT_EPH.txt
# document is in 16 chunks
# filename: QXNWBT_2JN.txt
# document is in 1 chunks
# filename: QXNDPI_JER.txt
# document is in 122 chunks
# dialect: qxo
# filename: QXOLLB_1TH.txt
# document is in 8 chunks
# filename: QXOLLB_MRK.txt
# document is in 55 chunks
# filename: QXOLLB_TIT.txt
# document is in 5 chunks
# filename: QXOLLB_1TI.txt
# document is in 11 chunks
# filename: QXOLLB_EPH.txt
# document is in 12 chunks
# filename: QXOLLB_2JN.txt
# document is in 1 chunks
# filename: QXOLLB_REV.txt
# document is in 42 chunks
# filename: QXOLLB_2PE.txt
# document is in 7 chunks
# filename: QXOLLB_LUK.txt
# document is in 93 chunks
# filename: QXOLLB_PHP.txt
# document is in 9 chunks
# filename: QXOLLB_2TI.txt
# document is in 8 chunks
# filename: QXOLLB_COL.txt
# document is in 8 chunks
# filename: QXOLLB_3JN.txt
# document is in 1 chunks
# filename: QXOLLB_2TH.txt
# document is in 4 chunks
# filename: QXOLLB_1JN.txt
# document is in 10 chunks
# filename: QXOLLB_1PE.txt
# document is in 11 chunks
# filename: QXOLLB_HEB.txt
# document is in 30 chunks
# filename: QXOLLB_ROM.txt
# document is in 40 chunks
# filename: QXOLLB_MAT.txt
# document is in 89 chunks
# filename: QXOLLB_GAL.txt
# document is in 15 chunks
# filename: QXOLLB_2CO.txt
# document is in 24 chunks
# filename: QXOLLB_JHN.txt
# document is in 69 chunks
# filename: QXOLLB_ACT.txt
# document is in 91 chunks
# filename: QXOLLB_JAS.txt
# document is in 10 chunks
# filename: QXOLLB_PHM.txt
# document is in 2 chunks
# filename: QXOLLB_1CO.txt
# document is in 39 chunks
# filename: QXOLLB_JUD.txt
# document is in 4 chunks
# dialect: qxr
# filename: QXRBSE_DEU.txt
# document is in 77 chunks
# filename: QXRBSE_MAT.txt
# document is in 77 chunks
# filename: QXRBSE_RUT.txt
# document is in 9 chunks
# filename: QXRBSE_NEH.txt
# document is in 34 chunks
# filename: QXRBSE_ROM.txt
# document is in 33 chunks
# filename: QXRBSE_ECC.txt
# document is in 19 chunks
# filename: QXRBSE_2CH.txt
# document is in 91 chunks
# filename: QXRBSE_AMO.txt
# document is in 14 chunks
# filename: QXRBSE_EXO.txt
# document is in 95 chunks
# filename: QXRBSE_ACT.txt
# document is in 80 chunks
# filename: QXRBSE_1SA.txt
# document is in 84 chunks
# filename: QXRBSE_EZR.txt
# document is in 24 chunks
# filename: QXRBSE_GAL.txt
# document is in 13 chunks
# filename: QXRBSE_2CO.txt
# document is in 23 chunks
# filename: QXRBSE_JHN.txt
# document is in 64 chunks
# filename: QXRBSE_ISA.txt
# document is in 118 chunks
# filename: QXRBSE_JOL.txt
# document is in 7 chunks
# filename: QXRBSE_HAG.txt
# document is in 4 chunks
# filename: QXRBSE_JON.txt
# document is in 4 chunks
# filename: QXRBSE_PSA.txt
# document is in 146 chunks
# filename: QXRBSE_ZEP.txt
# document is in 5 chunks
# filename: QXRBSE_JAS.txt
# document is in 9 chunks
# filename: QXRBSE_1CH.txt
# document is in 68 chunks
# filename: QXRBSE_HAB.txt
# document is in 5 chunks
# filename: QXRBSE_ZEC.txt
# document is in 20 chunks
# filename: QXRBSE_DAN.txt
# document is in 38 chunks
# filename: QXRBSE_JUD.txt
# document is in 3 chunks
# filename: QXRBSE_1CO.txt
# document is in 34 chunks
# filename: QXRBSE_PHM.txt
# document is in 2 chunks
# filename: QXRBSE_2SA.txt
# document is in 68 chunks
# filename: QXRBSE_JOS.txt
# document is in 60 chunks
# filename: QXRBSE_2JN.txt
# document is in 1 chunks
# filename: QXRBSE_EPH.txt
# document is in 13 chunks
# filename: QXRBSE_PRO.txt
# document is in 56 chunks
# filename: QXRBSE_MIC.txt
# document is in 10 chunks
# filename: QXRBSE_MRK.txt
# document is in 49 chunks
# filename: QXRBSE_1TI.txt
# document is in 10 chunks
# filename: QXRBSE_TIT.txt
# document is in 4 chunks
# filename: QXRBSE_NUM.txt
# document is in 96 chunks
# filename: QXRBSE_2KI.txt
# document is in 79 chunks
# filename: QXRBSE_1TH.txt
# document is in 7 chunks
# filename: QXRBSE_HOS.txt
# document is in 18 chunks
# filename: QXRBSE_JOB.txt
# document is in 61 chunks
# filename: QXRBSE_EST.txt
# document is in 20 chunks
# filename: QXRBSE_NAM.txt
# document is in 5 chunks
# filename: QXRBSE_PHP.txt
# document is in 9 chunks
# filename: QXRBSE_LUK.txt
# document is in 83 chunks
# filename: QXRBSE_SNG.txt
# document is in 10 chunks
# filename: QXRBSE_2PE.txt
# document is in 7 chunks
# filename: QXRBSE_GEN.txt
# document is in 121 chunks
# filename: QXRBSE_LAM.txt
# document is in 11 chunks
# filename: QXRBSE_REV.txt
# document is in 43 chunks
# filename: QXRBSE_JER.txt
# document is in 130 chunks
# filename: QXRBSE_1JN.txt
# document is in 9 chunks
# filename: QXRBSE_3JN.txt
# document is in 1 chunks
# filename: QXRBSE_LEV.txt
# document is in 68 chunks
# filename: QXRBSE_2TH.txt
# document is in 4 chunks
# filename: QXRBSE_EZK.txt
# document is in 112 chunks
# filename: QXRBSE_2TI.txt
# document is in 7 chunks
# filename: QXRBSE_COL.txt
# document is in 9 chunks
# filename: QXRBSE_1KI.txt
# document is in 86 chunks
# filename: QXRBSE_MAL.txt
# document is in 7 chunks
# filename: QXRBSE_JDG.txt
# document is in 60 chunks
# filename: QXRBSE_OBA.txt
# document is in 3 chunks
# filename: QXRBSE_1PE.txt
# document is in 10 chunks
# filename: QXRBSE_HEB.txt
# document is in 24 chunks

# %%
# Create the dataset directly from a dictionary
dataset = Dataset.from_dict({'input_ids': [x['input_ids'] for x in processed_data],
                             'attention_mask': [x['attention_mask'] for x in processed_data],
                             'labels': [x['labels'] for x in processed_data]})
dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
split_datasets = dataset.train_test_split(test_size=0.15)
train_dataset = split_datasets['train']
val_dataset = split_datasets['test']

train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset, batch_size=8, collate_fn=collate_fn, sampler=train_sampler)

# %%
# List to store accuracy per epoch
epoch_accuracy = []

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)
    epoch_accuracy.append(acc)  # Store accuracy
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=1,  # Increased epochs
    # per_device_train_batch_size=10,  # Slightly larger batch size - original
    per_device_train_batch_size=20,  # Slightly larger batch size
    per_device_eval_batch_size=15,
    warmup_steps=500,  # Adjusted warmup steps
    weight_decay=0.01,  # Adjusted weight decay
    # learning_rate=5e-5,  # Added explicit learning rate
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",
    lr_scheduler_type='cosine',  # Using a cosine learning rate scheduler
    save_strategy="epoch",  # Save the model at each epoch
    load_best_model_at_end=True,  # Load the best model at the end of training
    metric_for_best_model="accuracy"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# /Users/clairepost/opt/anaconda3/envs/nlp_hw/lib/python3.11/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 22385
#   Num Epochs = 1
#   Instantaneous batch size per device = 20
#   Total train batch size (w. parallel, distributed & accumulation) = 20
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1120
#   Number of trainable parameters = 83471643
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#   0%|          | 0/1120 [00:00<?, ?it/s]
# {'loss': 3.3279, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.01}
# {'loss': 3.3011, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.02}
# {'loss': 3.269, 'learning_rate': 3e-06, 'epoch': 0.03}
# {'loss': 3.1483, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.04}
# {'loss': 3.0936, 'learning_rate': 5e-06, 'epoch': 0.04}
# {'loss': 3.0613, 'learning_rate': 6e-06, 'epoch': 0.05}
# {'loss': 3.0412, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.06}
# {'loss': 2.8872, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.07}
# {'loss': 2.8944, 'learning_rate': 9e-06, 'epoch': 0.08}
# {'loss': 2.8629, 'learning_rate': 1e-05, 'epoch': 0.09}
# {'loss': 2.6962, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.1}
# {'loss': 2.5585, 'learning_rate': 1.2e-05, 'epoch': 0.11}
# {'loss': 2.3242, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.12}
# {'loss': 2.3319, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.12}
# {'loss': 2.0903, 'learning_rate': 1.5e-05, 'epoch': 0.13}
# {'loss': 2.0753, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.14}
# {'loss': 1.8789, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.15}
# {'loss': 1.8276, 'learning_rate': 1.8e-05, 'epoch': 0.16}
# {'loss': 1.6521, 'learning_rate': 1.9e-05, 'epoch': 0.17}
# {'loss': 1.6471, 'learning_rate': 2e-05, 'epoch': 0.18}
# {'loss': 1.4892, 'learning_rate': 2.1e-05, 'epoch': 0.19}
# {'loss': 1.3826, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.2}
# {'loss': 1.4674, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.21}
# {'loss': 1.4313, 'learning_rate': 2.4e-05, 'epoch': 0.21}
# {'loss': 1.2517, 'learning_rate': 2.5e-05, 'epoch': 0.22}
# {'loss': 1.1938, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.23}
# {'loss': 1.1844, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.24}
# {'loss': 1.1015, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.25}
# {'loss': 1.1225, 'learning_rate': 2.9e-05, 'epoch': 0.26}
# {'loss': 1.0177, 'learning_rate': 3e-05, 'epoch': 0.27}
# {'loss': 0.9253, 'learning_rate': 3.1e-05, 'epoch': 0.28}
# {'loss': 0.8199, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.29}
# {'loss': 0.7678, 'learning_rate': 3.3e-05, 'epoch': 0.29}
# {'loss': 0.7752, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.3}
# {'loss': 0.6987, 'learning_rate': 3.5e-05, 'epoch': 0.31}
# {'loss': 0.6125, 'learning_rate': 3.6e-05, 'epoch': 0.32}
# {'loss': 0.6559, 'learning_rate': 3.7e-05, 'epoch': 0.33}
# {'loss': 0.611, 'learning_rate': 3.8e-05, 'epoch': 0.34}
# {'loss': 0.5448, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.35}
# {'loss': 0.4556, 'learning_rate': 4e-05, 'epoch': 0.36}
# {'loss': 0.4297, 'learning_rate': 4.1e-05, 'epoch': 0.37}
# {'loss': 0.4154, 'learning_rate': 4.2e-05, 'epoch': 0.38}
# {'loss': 0.3509, 'learning_rate': 4.3e-05, 'epoch': 0.38}
# {'loss': 0.3565, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.39}
# {'loss': 0.3441, 'learning_rate': 4.5e-05, 'epoch': 0.4}
# {'loss': 0.2701, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.41}
# {'loss': 0.1799, 'learning_rate': 4.7e-05, 'epoch': 0.42}
# {'loss': 0.2308, 'learning_rate': 4.8e-05, 'epoch': 0.43}
# {'loss': 0.2157, 'learning_rate': 4.9e-05, 'epoch': 0.44}
# {'loss': 0.1481, 'learning_rate': 5e-05, 'epoch': 0.45}
# {'loss': 0.162, 'learning_rate': 4.9967912679276316e-05, 'epoch': 0.46}
# {'loss': 0.1465, 'learning_rate': 4.987173308479738e-05, 'epoch': 0.46}
# {'loss': 0.1564, 'learning_rate': 4.971170810820279e-05, 'epoch': 0.47}
# {'loss': 0.1408, 'learning_rate': 4.948824853131236e-05, 'epoch': 0.48}
# {'loss': 0.1708, 'learning_rate': 4.920192797165511e-05, 'epoch': 0.49}
# {'loss': 0.1351, 'learning_rate': 4.885348141000122e-05, 'epoch': 0.5}
# {'loss': 0.1421, 'learning_rate': 4.844380330367701e-05, 'epoch': 0.51}
# {'loss': 0.1491, 'learning_rate': 4.7973945290505766e-05, 'epoch': 0.52}
# {'loss': 0.1663, 'learning_rate': 4.7445113489268544e-05, 'epoch': 0.53}
# {'loss': 0.0838, 'learning_rate': 4.685866540361456e-05, 'epoch': 0.54}
# {'loss': 0.0781, 'learning_rate': 4.621610643736878e-05, 'epoch': 0.54}
# {'loss': 0.0806, 'learning_rate': 4.551908603018191e-05, 'epoch': 0.55}
# {'loss': 0.079, 'learning_rate': 4.476939342344246e-05, 'epoch': 0.56}
# {'loss': 0.0654, 'learning_rate': 4.3968953067319777e-05, 'epoch': 0.57}
# {'loss': 0.0593, 'learning_rate': 4.3119819680728e-05, 'epoch': 0.58}
# {'loss': 0.0303, 'learning_rate': 4.222417297689217e-05, 'epoch': 0.59}
# {'loss': 0.0696, 'learning_rate': 4.128431206805557e-05, 'epoch': 0.6}
# {'loss': 0.0838, 'learning_rate': 4.030264956369157e-05, 'epoch': 0.61}
# {'loss': 0.026, 'learning_rate': 3.928170537736981e-05, 'epoch': 0.62}
# {'loss': 0.0592, 'learning_rate': 3.822410025817406e-05, 'epoch': 0.62}
# {'loss': 0.0373, 'learning_rate': 3.713254906327703e-05, 'epoch': 0.63}
# {'loss': 0.034, 'learning_rate': 3.600985378894086e-05, 'epoch': 0.64}
# {'loss': 0.0284, 'learning_rate': 3.4858896377832966e-05, 'epoch': 0.65}
# {'loss': 0.0368, 'learning_rate': 3.3682631321120504e-05, 'epoch': 0.66}
# {'loss': 0.1006, 'learning_rate': 3.2484078074333954e-05, 'epoch': 0.67}
# {'loss': 0.0252, 'learning_rate': 3.126631330646802e-05, 'epoch': 0.68}
# {'loss': 0.0454, 'learning_rate': 3.0032463002216505e-05, 'epoch': 0.69}
# {'loss': 0.0357, 'learning_rate': 2.878569443761442e-05, 'epoch': 0.7}
# {'loss': 0.0363, 'learning_rate': 2.7529208049685807e-05, 'epoch': 0.71}
# {'loss': 0.0218, 'learning_rate': 2.6266229220967818e-05, 'epoch': 0.71}
# {'loss': 0.0198, 'learning_rate': 2.5e-05, 'epoch': 0.72}
# {'loss': 0.0216, 'learning_rate': 2.3733770779032184e-05, 'epoch': 0.73}
# {'loss': 0.0729, 'learning_rate': 2.24707919503142e-05, 'epoch': 0.74}
# {'loss': 0.0403, 'learning_rate': 2.1214305562385592e-05, 'epoch': 0.75}
# {'loss': 0.0254, 'learning_rate': 1.9967536997783494e-05, 'epoch': 0.76}
# {'loss': 0.0411, 'learning_rate': 1.8733686693531985e-05, 'epoch': 0.77}
# {'loss': 0.0174, 'learning_rate': 1.7515921925666052e-05, 'epoch': 0.78}
# {'loss': 0.0258, 'learning_rate': 1.6317368678879495e-05, 'epoch': 0.79}
# {'loss': 0.0139, 'learning_rate': 1.5141103622167041e-05, 'epoch': 0.79}
# {'loss': 0.015, 'learning_rate': 1.399014621105914e-05, 'epoch': 0.8}
# {'loss': 0.0258, 'learning_rate': 1.286745093672298e-05, 'epoch': 0.81}
# {'loss': 0.0139, 'learning_rate': 1.1775899741825947e-05, 'epoch': 0.82}
# {'loss': 0.0091, 'learning_rate': 1.0718294622630188e-05, 'epoch': 0.83}
# {'loss': 0.0325, 'learning_rate': 9.697350436308427e-06, 'epoch': 0.84}
# {'loss': 0.041, 'learning_rate': 8.715687931944449e-06, 'epoch': 0.85}
# {'loss': 0.0267, 'learning_rate': 7.775827023107835e-06, 'epoch': 0.86}
# {'loss': 0.0258, 'learning_rate': 6.880180319272006e-06, 'epoch': 0.87}
# {'loss': 0.0335, 'learning_rate': 6.031046932680226e-06, 'epoch': 0.88}
# {'loss': 0.0214, 'learning_rate': 5.23060657655754e-06, 'epoch': 0.88}
# {'loss': 0.0088, 'learning_rate': 4.480913969818098e-06, 'epoch': 0.89}
# {'loss': 0.0067, 'learning_rate': 3.7838935626312242e-06, 'epoch': 0.9}
# {'loss': 0.007, 'learning_rate': 3.141334596385448e-06, 'epoch': 0.91}
# {'loss': 0.0401, 'learning_rate': 2.5548865107314607e-06, 'epoch': 0.92}
# {'loss': 0.0166, 'learning_rate': 2.026054709494235e-06, 'epoch': 0.93}
# {'loss': 0.0132, 'learning_rate': 1.5561966963229924e-06, 'epoch': 0.94}
# {'loss': 0.0309, 'learning_rate': 1.1465185899987797e-06, 'epoch': 0.95}
# {'loss': 0.0085, 'learning_rate': 7.980720283448956e-07, 'epoch': 0.96}
# {'loss': 0.0084, 'learning_rate': 5.117514686876379e-07, 'epoch': 0.96}
# {'loss': 0.0163, 'learning_rate': 2.8829189179721547e-07, 'epoch': 0.97}
# {'loss': 0.0183, 'learning_rate': 1.2826691520262114e-07, 'epoch': 0.98}
# {'loss': 0.0105, 'learning_rate': 3.208732072368104e-08, 'epoch': 0.99}
# ***** Running Evaluation *****
#   Num examples = 3951
#   Batch size = 15
# {'loss': 0.0989, 'learning_rate': 0.0, 'epoch': 1.0}
#   0%|          | 0/264 [00:00<?, ?it/s]
# Saving model checkpoint to ./results/checkpoint-1120
# Configuration saved in ./results/checkpoint-1120/config.json
# {'eval_loss': 0.02189275063574314, 'eval_accuracy': 0.9967096937484181, 'eval_f1': 0.9967114495185905, 'eval_precision': 0.9967603608779289, 'eval_recall': 0.9967096937484181, 'eval_runtime': 401.2632, 'eval_samples_per_second': 9.846, 'eval_steps_per_second': 0.658, 'epoch': 1.0}
# Model weights saved in ./results/checkpoint-1120/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./results/checkpoint-1120 (score: 0.9967096937484181).
# {'train_runtime': 13118.7961, 'train_samples_per_second': 1.706, 'train_steps_per_second': 0.085, 'train_loss': 0.6938534443865397, 'epoch': 1.0}
# TrainOutput(global_step=1120, training_loss=0.6938534443865397, metrics={'train_runtime': 13118.7961, 'train_samples_per_second': 1.706, 'train_steps_per_second': 0.085, 'train_loss': 0.6938534443865397, 'epoch': 1.0})

# %% [markdown]
# Train the model then save the model path so it can be used for unclassified data

# %%
model_path = './models/neural_rules_3'
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# Configuration saved in ./models/neural_rules_3/config.json
# Model weights saved in ./models/neural_rules_3/pytorch_model.bin
# tokenizer config file saved in ./models/neural_rules_3/tokenizer_config.json
# Special tokens file saved in ./models/neural_rules_3/special_tokens_map.json
# ('./models/neural_rules_3/tokenizer_config.json',
#  './models/neural_rules_3/special_tokens_map.json',
#  './models/neural_rules_3/vocab.json',
#  './models/neural_rules_3/merges.txt',
#  './models/neural_rules_3/added_tokens.json',
#  './models/neural_rules_3/tokenizer.json')

# %%
def get_predictions(model, dataloader):
    model.eval()  # Put model in evaluation mode
    predictions = []
    true_labels = []
    
    with torch.no_grad():
        for batch in dataloader:
            inputs = {'input_ids': batch['input_ids'].to(model.device),
                      'attention_mask': batch['attention_mask'].to(model.device)}
            outputs = model(**inputs)
            logits = outputs.logits
            preds = torch.argmax(logits, dim=-1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(batch['labels'].cpu().numpy())
    
    return predictions, true_labels

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predict on the validation set
predictions = trainer.predict(val_dataset)
predicted_labels = np.argmax(predictions.predictions, axis=-1)
true_labels = predictions.label_ids

# Plot training loss
training_loss = trainer.state.log_history

epochs = [x['epoch'] for x in training_loss if 'loss' in x]
loss = [x['loss'] for x in training_loss if 'loss' in x]

plt.figure(figsize=(10, 5))
plt.plot(epochs, loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ***** Running Prediction *****
#   Num examples = 3951
#   Batch size = 15
#   0%|          | 0/264 [00:00<?, ?it/s]

# %%
from sklearn.metrics import classification_report

# Assuming you have a DataLoader for your validation dataset
val_dataloader = DataLoader(val_dataset, batch_size=32, collate_fn=collate_fn)  # Adjust batch size as needed

# Get predictions
predictions, true_labels = get_predictions(model, val_dataloader)

# Generate classification report
report = classification_report(true_labels, predictions, target_names=[label for label in directory_paths.keys()])
print("Classification Report:\n", report)
# Out:
# /var/folders/fs/xcmh2x8j5zdc3l6qxd_9cy7w0000gn/T/ipykernel_88978/64439305.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_ids = pad_sequence([torch.tensor(seq) for seq in input_ids], batch_first=True, padding_value=tokenizer.pad_token_id)
# /var/folders/fs/xcmh2x8j5zdc3l6qxd_9cy7w0000gn/T/ipykernel_88978/64439305.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   attention_masks = pad_sequence([torch.tensor(mask) for mask in attention_masks], batch_first=True, padding_value=0)
# Classification Report:
#                precision    recall  f1-score   support
#
#          inb       0.99      1.00      1.00       115
#          qub       0.99      1.00      0.99        84
#          quf       1.00      1.00      1.00       107
#          quh       1.00      1.00      1.00        92
#          qul       1.00      1.00      1.00       100
#          qup       1.00      0.99      1.00       146
#          quw       1.00      1.00      1.00        95
#          quy       0.98      1.00      0.99       448
#          quz       1.00      0.98      0.99       435
#          qvc       1.00      1.00      1.00       109
#          qve       1.00      1.00      1.00       140
#          qvi       1.00      1.00      1.00       113
#          qvh       0.99      0.99      0.99        83
#          qvm       1.00      0.99      1.00       115
#          qvn       1.00      1.00      1.00       101
#          qvo       1.00      1.00      1.00        78
#          qvs       1.00      1.00      1.00       122
#          qvw       1.00      1.00      1.00        81
#          qvz       1.00      0.99      1.00       132
#          qwh       1.00      1.00      1.00       175
#          qxl       1.00      1.00      1.00       100
#          qxh       1.00      1.00      1.00        92
#          qxn       1.00      1.00      1.00       390
#          qxo       1.00      1.00      1.00       114
#          qxr       1.00      1.00      1.00       384
#
#     accuracy                           1.00      3951
#    macro avg       1.00      1.00      1.00      3951
# weighted avg       1.00      1.00      1.00      3951

# %%
# Extract dialect names from the directory paths
dialect_labels = list(directory_paths.keys())

# Generate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
# Create a confusion matrix display object
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dialect_labels)

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(14, 14))  # Adjust size as necessary for readability
disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical')
ax.set_title('Confusion Matrix for Quechua Dialect Classification')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(true_labels, predictions, labels=list(range(len(directory_paths))))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[label for label in directory_paths.keys()])

# Increase figure size
plt.figure(figsize=(10, 7))  # Adjust the size as needed
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=90, fontsize=10)  # Rotate labels and adjust font size
plt.yticks(fontsize=10)
plt.tight_layout()  # Adjust layout
plt.title("Counts Confusion Matrix")
plt.show()

# %% [markdown]
# Normalized Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(true_labels, predictions, labels=list(range(len(directory_paths))), normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[label for label in directory_paths.keys()])

# Increase figure size
plt.figure(figsize=(10, 7))  # Adjust the size as needed
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=90, fontsize=10)  # Rotate labels and adjust font size
plt.yticks(fontsize=10)
plt.title("Normalized Confusion Matrix")
plt.tight_layout()  # Adjust layout
plt.show()

# %%
plt.plot(epoch_accuracy)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import classification_report
import pandas as pd
import matplotlib.pyplot as plt

report = classification_report(true_labels, predictions, target_names=directory_paths.keys(), output_dict=True)
report_df = pd.DataFrame(report).transpose()

report_df.drop(['accuracy', 'macro avg', 'weighted avg'], inplace=True)  # Drop averages/total
report_df[['precision', 'recall', 'f1-score']].plot(kind='bar', figsize=(12, 6))
plt.title('Classification Report for Each Class')
plt.ylabel('Score')
plt.show()
